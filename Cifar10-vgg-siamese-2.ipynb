# %%
import tensorflow as tf
from matplotlib import pyplot
from keras.datasets import cifar10
from tensorflow.keras import *
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import *

import random

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

Y_train = y_train
Y_test = y_test


num_classes = 10 
x_train = x_train/255.
y_train = utils.to_categorical(y_train, num_classes) 

x_test = x_test/255.
y_test = utils.to_categorical(y_test, num_classes)

# %%
##########################################Functions to rename vgg19 model ###################################

def add_infix(a,b,character):  
    b.startswith(a)
    tail = b.split(a, 1)[1]
    b = a + character + tail
    return b

add_infix('block1_conv1','block1_conv1_ib-0','A')

def rename_network_nodes(vgg19,character):  # https://stackoverflow.com/questions/63373692/how-to-rename-the-layers-of-a-keras-model-without-corrupting-the-structure
    layer_names = {layer._name for layer in vgg19.layers}
    _network_nodes = []
    for b in vgg19._network_nodes:
        for a in layer_names:
            if(b.startswith(a)):
                _network_nodes.append(add_infix(a,b,character))
    vgg19._network_nodes = set(_network_nodes)
    
def rename(vgg19,character):        
    rename_network_nodes(vgg19,character)
    
    vgg19._name = vgg19._name + f"{character}"
    for layer in vgg19.layers:
        layer._name = layer._name + f"{character}"

######################################################################################################

# %%
def build_model(weight_decay= 0.0005, x_shape=[32,32,3], num_classes=10):
        # Build the network of vgg for 10 classes with massive dropout and weight decay as described in the paper.

    model = Sequential()
#     model.add(Input(shape=()))

    model.add(Conv2D(64, (3, 3), padding='same',
                         input_shape=x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(2, 2)))


    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(2, 2)))


    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

#     model.add(Dropout(0.5))
#     model.add(Dense(num_classes))
#     model.add(Activation('softmax'))
    return model

# %%
########################################## Building siamese network ###################################


def build_siamese_vgg_model(shape, class_num):
    inputs1 = Input(shape)
    inputs2 = Input(shape)
    

    x1 = build_model()
    x2 = build_model()

    x = layers.concatenate([x1.outputs[0], x2.outputs[0]])
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)  

    # build the model
    model = Model([x1.inputs[0], x2.inputs[0]], outputs)
    
    model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    return model

model = build_siamese_vgg_model(x_train[0].shape, num_classes)

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# conv2d_input (InputLayer)       [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_13_input (InputLayer)    [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        conv2d_input[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   1792        conv2d_13_input[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 64)   256         activation_14[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   36928       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   36928       dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 64)   256         activation_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 128)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 128)  512         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 128)  512         activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 128)  147584      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 128)  147584      dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 128)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 128)  512         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 128)  512         activation_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    295168      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 256)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 256)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 256)    1024        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 256)    1024        activation_18[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 256)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 8, 8, 256)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 256)    590080      dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 256)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 256)    0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 256)    1024        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 256)    1024        activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 256)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 256)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 256)    590080      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 256)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 256)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 256)    1024        activation_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 512)    1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 512)    1180160     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 512)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 512)    2048        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 512)    2048        activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 512)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 4, 4, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 512)    2359808     dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 512)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 512)    0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 512)    2048        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 512)    2048        activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 4, 4, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 4, 4, 512)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 512)    2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 512)    2359808     dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 512)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 512)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 512)    2048        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 512)    2048        activation_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 2, 2, 512)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 2, 2, 512)    2359808     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 512)    2359808     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 2, 2, 512)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 2, 2, 512)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 2, 2, 512)    2048        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 2, 2, 512)    2048        activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 2, 2, 512)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 2, 2, 512)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 2, 2, 512)    2359808     dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 512)    2359808     dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 2, 2, 512)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 2, 2, 512)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 2, 2, 512)    2048        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 2, 2, 512)    2048        activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 2, 2, 512)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 2, 2, 512)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 2, 2, 512)    2359808     dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 2, 2, 512)    2359808     dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 2, 2, 512)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 2, 2, 512)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 2, 2, 512)    2048        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 2, 2, 512)    2048        activation_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 512)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 1, 1, 512)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1, 1, 512)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 1, 1, 512)    0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           dropout_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           dropout_17[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          262656      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      flatten_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 512)          2048        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 512)          2048        activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1024)         0           batch_normalization_13[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           10250       concatenate[0][0]
# ==================================================================================================
# Total params: 30,002,826
# Trainable params: 29,983,882
# Non-trainable params: 18,944
# __________________________________________________________________________________________________
# None

# %%
# x2.summary()

# %%
# x1 = build_model()
# # print(x1.summary())
# x2 = build_model()
# # print(x2.summary())

# x = layers.concatenate([x1.outputs[0], x2.outputs[0]])

# %%
def make_pairs(images, labels):
    pairImages = []
    pairLabels = []

    numClasses = len(np.unique(labels))
    idx = [np.where(labels == i)[0] for i in range(0, numClasses)]

    for idxA in range(len(images)):
        currentImage = images[idxA]
        label = labels[idxA]
#         print(currentImage.shape, label)

        
        for idxB in random.sample(list(idx[label[0]]), 1):
            posImage = images[idxB]
#             print(posImage.shape)
#             print('\n\n\n')


            pairImages.append(np.array([currentImage, posImage]))
            pairLabels.append(np.array(label))
        
    return np.array(pairImages), np.array(pairLabels)

# %%
######################################################################################################

x_train_siamese, y_train_siamese = make_pairs(x_train, Y_train)
x_test_siamese, y_test_siamese = make_pairs(x_test, Y_test)

y_train_siamese = utils.to_categorical(y_train_siamese, num_classes) 
y_test_siamese = utils.to_categorical(y_test_siamese, num_classes) 

x_train_both = [x_train_siamese[:,0,:], x_train_siamese[:,1,:]]
x_test_both = [x_test_siamese[:,0,:], x_test_siamese[:,1,:]]


print('Images')
print(np.array(x_train_both).shape)
print(np.array(x_test_both).shape)


print('Labels')
print(y_train_siamese.shape)
print(y_test_siamese.shape)
# Out:
# Images
# (2, 50000, 32, 32, 3)
# (2, 10000, 32, 32, 3)
# Labels
# (50000, 10)
# (10000, 10)

# %%
# print(model.summary())

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=30)

history3 = model.fit(x_train_both, y_train_siamese, epochs=400, batch_size=512, shuffle=True,
         validation_data=(x_test_both, y_test_siamese),callbacks=[callback])


print('Saving model')
model.save('model.h5')
# Out:
# Epoch 1/50
# 98/98 [==============================] - 28s 171ms/step - loss: 7.1824 - accuracy: 0.1279 - val_loss: 6.7765 - val_accuracy: 0.1000
# Epoch 2/50
# 98/98 [==============================] - 14s 138ms/step - loss: 6.6557 - accuracy: 0.2191 - val_loss: 7.2342 - val_accuracy: 0.1001
# Epoch 3/50
# 98/98 [==============================] - 14s 138ms/step - loss: 6.3062 - accuracy: 0.2929 - val_loss: 8.3008 - val_accuracy: 0.1004
# Epoch 4/50
# 98/98 [==============================] - 13s 138ms/step - loss: 6.1198 - accuracy: 0.3440 - val_loss: 9.0661 - val_accuracy: 0.1004
# Epoch 5/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.9979 - accuracy: 0.3736 - val_loss: 8.5711 - val_accuracy: 0.1141
# Epoch 6/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.8953 - accuracy: 0.4051 - val_loss: 7.6755 - val_accuracy: 0.1524
# Epoch 7/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.8158 - accuracy: 0.4294 - val_loss: 8.2753 - val_accuracy: 0.1385
# Epoch 8/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.7367 - accuracy: 0.4554 - val_loss: 8.0059 - val_accuracy: 0.1495
# Epoch 9/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.6686 - accuracy: 0.4797 - val_loss: 6.8223 - val_accuracy: 0.2866
# Epoch 10/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.6093 - accuracy: 0.4958 - val_loss: 7.3195 - val_accuracy: 0.2420
# Epoch 11/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.5482 - accuracy: 0.5173 - val_loss: 6.5958 - val_accuracy: 0.3204
# Epoch 12/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.5016 - accuracy: 0.5313 - val_loss: 6.8271 - val_accuracy: 0.3090
# Epoch 13/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.4531 - accuracy: 0.5471 - val_loss: 7.1786 - val_accuracy: 0.2885
# Epoch 14/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.4124 - accuracy: 0.5620 - val_loss: 7.1069 - val_accuracy: 0.2841
# Epoch 15/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.3645 - accuracy: 0.5783 - val_loss: 6.3706 - val_accuracy: 0.3879
# Epoch 16/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.3196 - accuracy: 0.5955 - val_loss: 6.7283 - val_accuracy: 0.3481
# Epoch 17/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.2809 - accuracy: 0.6062 - val_loss: 7.1904 - val_accuracy: 0.3044
# Epoch 18/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.2458 - accuracy: 0.6200 - val_loss: 6.8528 - val_accuracy: 0.3401
# Epoch 19/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.2040 - accuracy: 0.6340 - val_loss: 7.1156 - val_accuracy: 0.3038
# Epoch 20/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.1711 - accuracy: 0.6438 - val_loss: 6.4110 - val_accuracy: 0.3878
# Epoch 21/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.1347 - accuracy: 0.6541 - val_loss: 6.7132 - val_accuracy: 0.3685
# Epoch 22/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.1032 - accuracy: 0.6632 - val_loss: 6.3130 - val_accuracy: 0.4048
# Epoch 23/50
# 98/98 [==============================] - 14s 138ms/step - loss: 5.0631 - accuracy: 0.6765 - val_loss: 6.4690 - val_accuracy: 0.4006
# Epoch 24/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.0335 - accuracy: 0.6848 - val_loss: 6.6522 - val_accuracy: 0.3728
# Epoch 25/50
# 98/98 [==============================] - 13s 138ms/step - loss: 5.0036 - accuracy: 0.6953 - val_loss: 6.2813 - val_accuracy: 0.4229
# Epoch 26/50
# 98/98 [==============================] - 14s 138ms/step - loss: 4.9815 - accuracy: 0.7004 - val_loss: 6.4961 - val_accuracy: 0.4105
# Epoch 27/50
# 98/98 [==============================] - 13s 138ms/step - loss: 4.9442 - accuracy: 0.7116 - val_loss: 5.9132 - val_accuracy: 0.4812
# Epoch 28/50
# 98/98 [==============================] - 13s 138ms/step - loss: 4.9182 - accuracy: 0.7195 - val_loss: 5.8729 - val_accuracy: 0.4887
# Epoch 29/50
# 98/98 [==============================] - 13s 138ms/step - loss: 4.9007 - accuracy: 0.7211 - val_loss: 6.0430 - val_accuracy: 0.4542
# Epoch 30/50
# 98/98 [==============================] - 14s 139ms/step - loss: 4.8775 - accuracy: 0.7271 - val_loss: 5.5082 - val_accuracy: 0.5582
# Epoch 31/50
# 98/98 [==============================] - 14s 140ms/step - loss: 4.8552 - accuracy: 0.7341 - val_loss: 5.8242 - val_accuracy: 0.4896
# Epoch 32/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.8353 - accuracy: 0.7359 - val_loss: 6.2623 - val_accuracy: 0.4282
# Epoch 33/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.8095 - accuracy: 0.7478 - val_loss: 5.6867 - val_accuracy: 0.5286
# Epoch 34/50
# 98/98 [==============================] - 14s 143ms/step - loss: 4.7912 - accuracy: 0.7491 - val_loss: 5.7117 - val_accuracy: 0.5157
# Epoch 35/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.7705 - accuracy: 0.7548 - val_loss: 5.7806 - val_accuracy: 0.5076
# Epoch 36/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.7480 - accuracy: 0.7574 - val_loss: 5.5362 - val_accuracy: 0.5527
# Epoch 37/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.7233 - accuracy: 0.7665 - val_loss: 5.6936 - val_accuracy: 0.5162
# Epoch 38/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.7105 - accuracy: 0.7668 - val_loss: 5.4365 - val_accuracy: 0.5746
# Epoch 39/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.6890 - accuracy: 0.7737 - val_loss: 5.4998 - val_accuracy: 0.5621
# Epoch 40/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.6717 - accuracy: 0.7758 - val_loss: 5.7731 - val_accuracy: 0.5032
# Epoch 41/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.6559 - accuracy: 0.7803 - val_loss: 5.5198 - val_accuracy: 0.5614
# Epoch 42/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.6398 - accuracy: 0.7821 - val_loss: 5.7193 - val_accuracy: 0.5186
# Epoch 43/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.6248 - accuracy: 0.7853 - val_loss: 5.4555 - val_accuracy: 0.5826
# Epoch 44/50
# 98/98 [==============================] - 14s 141ms/step - loss: 4.6066 - accuracy: 0.7903 - val_loss: 5.4835 - val_accuracy: 0.5619
# Epoch 45/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.5905 - accuracy: 0.7925 - val_loss: 5.5119 - val_accuracy: 0.5492
# Epoch 46/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.5739 - accuracy: 0.7957 - val_loss: 5.4177 - val_accuracy: 0.5731
# Epoch 47/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.5577 - accuracy: 0.8006 - val_loss: 5.6466 - val_accuracy: 0.5395
# Epoch 48/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.5457 - accuracy: 0.8008 - val_loss: 5.3835 - val_accuracy: 0.5916
# Epoch 49/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.5285 - accuracy: 0.8051 - val_loss: 5.1433 - val_accuracy: 0.6353
# Epoch 50/50
# 98/98 [==============================] - 14s 142ms/step - loss: 4.5150 - accuracy: 0.8053 - val_loss: 5.3172 - val_accuracy: 0.5982
# Saving model

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d27ced61af4> in <module>
# ----> 1 history3 = model.fit(x_train_both, y_train_siamese, epochs=300, batch_size=512, shuffle=True,
#       2          validation_data=(x_test_both, y_test_siamese),callbacks=[callback])
#       3
#
# NameError: name 'model' is not defined
